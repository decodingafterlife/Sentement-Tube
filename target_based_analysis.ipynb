# %%
from googleapiclient.discovery import build
import json

def get_youtube_api_service(api_key):
    youtube_api_service = build('youtube', 'v3', developerKey=api_key)
    return youtube_api_service

def search_videos(api_service, keyword, max_results=10):
    search_response = api_service.search().list(
        q=keyword,
        part='id',
        type='video',
        maxResults=max_results,
        eventType='completed'  # Exclude live streams
    ).execute()

    video_ids = [item['id']['videoId'] for item in search_response['items']]
    return video_ids

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = "AIzaSyDFFVUkYavn8C3BMAssUShtVVz7NAupOlE"
    keyword = input("Enter the keyword to search for: ")

    youtube_api_service = get_youtube_api_service(api_key)
    video_ids = search_videos(youtube_api_service, keyword)

    print("Top Trending Videos for '{}':".format(keyword))
    for video_id in video_ids:
        print(video_id)

if __name__ == "__main__":
    main()
# Out:
# Enter the keyword to search for:  russia
# Top Trending Videos for 'russia':
# boUBy_exT_E
# 1O75DxrpqVI
# uAZwHpQB-Qw
# GXNnNC2RnJY
# DEByPo-AbFQ
# suyWQnfMggo
# vrbjjTWeHx0
# b6tOCdiMXTU
# 8aCXoaCHfPk
# CTLIOnT78iw

# %%
def get_video_details(api_service, video_id):
    video_response = api_service.videos().list(
        part='snippet',
        id=video_id
    ).execute()

    if 'items' in video_response and video_response['items']:
        return video_response['items'][0]['snippet']
    else:
        return None

# %%
video_id = input("Enter the YouTube video ID: ")

api_key = "AIzaSyDFFVUkYavn8C3BMAssUShtVVz7NAupOlE"

youtube_api_service = get_youtube_api_service(api_key)
video_details = get_video_details(youtube_api_service, video_id)

if video_details:
    title = video_details['title']
    description = video_details['description']

    print(f"Title: {title}")
    print(f"Description: {description}")
else:
    print("Video details not found.")
# Out:
# Enter the YouTube video ID:  9iqI6YLKYEY
# Title: How Hindutva Made Hinduism COOL AGAIN | Ram Mandir
# Description: There was a time when being Hindu and celebrating Hindu festivals was UNCOOL, while accepting rituals and traditions from the west made one cool in Indian society.
#
# Hindu festivals were always a day of activism and not celebration from save water to save air.
#
# But things have changed in the past 10 years, Hinduism is becoming COOL again. Celebrities too are joining the bandwagon.
#
# In this video, we will find out how Hindu achieved something that seemed impossible ￼.
#
# 0:00 Intro
# 1:46 Hinduism after Independance
# 7:16 Hinduism in Bollywood
# 11:30 Hinduism after Hindutva
# 18:47 BJP's contribution
#
# Link to Rapperiyabaalam  https://www.youtube.com/@rapperiyabaalamofficial
# Link to Shrylox https://www.youtube.com/channel/UCq7stsv9e05hU3wG_luSs0A
#
# 👚Buy New Sham Sharma Show Merch:
# https://kadakmerch.com/collections/the-sham-sharma-show
#
# ...

# %%
# !pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_youtube_api_service(api_key):
    youtube_api_service = build('youtube', 'v3', developerKey=api_key)
    return youtube_api_service

def get_video_details(api_service, video_id):
    video_response = api_service.videos().list(
        part='snippet',
        id=video_id
    ).execute()

    if 'items' in video_response and video_response['items']:
        return video_response['items'][0]['snippet']
    else:
        return None

def get_video_transcript(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return transcript
    except Exception as e:
        print(f"Error retrieving transcript: {str(e)}")
        return None

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = "AIzaSyDFFVUkYavn8C3BMAssUShtVVz7NAupOlE"
    video_id = input("Enter the YouTube video ID: ")

    youtube_api_service = get_youtube_api_service(api_key)
    video_details = get_video_details(youtube_api_service, video_id)

    if video_details:
        title = video_details['title']
        description = video_details['description']
        
        print(f"Title: {title}")
        print(f"Description: {description}")

        transcript = get_video_transcript(video_id)
        if transcript:
            print("\nTranscript:")
            for entry in transcript:
                print(f"{entry['start']} - {entry['start'] + entry['duration']}: {entry['text']}")
        else:
            print("Transcript not available.")
    else:
        print("Video details not found.")

if __name__ == "__main__":
    main()
# Out:
# Enter the YouTube video ID:  9iqI6YLKYEY
# Title: How Hindutva Made Hinduism COOL AGAIN | Ram Mandir
# Description: There was a time when being Hindu and celebrating Hindu festivals was UNCOOL, while accepting rituals and traditions from the west made one cool in Indian society.
#
# Hindu festivals were always a day of activism and not celebration from save water to save air.
#
# But things have changed in the past 10 years, Hinduism is becoming COOL again. Celebrities too are joining the bandwagon.
#
# In this video, we will find out how Hindu achieved something that seemed impossible ￼.
#
# 0:00 Intro
# 1:46 Hinduism after Independance
# 7:16 Hinduism in Bollywood
# 11:30 Hinduism after Hindutva
# 18:47 BJP's contribution
#
# Link to Rapperiyabaalam  https://www.youtube.com/@rapperiyabaalamofficial
# Link to Shrylox https://www.youtube.com/channel/UCq7stsv9e05hU3wG_luSs0A
#
# 👚Buy New Sham Sharma Show Merch:
# https://kadakmerch.com/collections/the-sham-sharma-show
#
# ...

# %%
from googleapiclient.discovery import build

def get_youtube_api_service(api_key):
    youtube_api_service = build('youtube', 'v3', developerKey=api_key)
    return youtube_api_service

def get_video_captions(api_service, video_id):
    captions_response = api_service.captions().list(
        part='snippet',
        videoId=video_id
    ).execute()

    english_captions = [caption for caption in captions_response.get('items', []) if caption['snippet']['language'] == 'en']
    return english_captions

def get_caption_text(api_service, caption_id):
    caption_response = api_service.captions().download(
        id=caption_id
    ).execute()

    return caption_response.decode('utf-8')

def main():
    # Replace 'YOUR_API_KEY' with your actual API key
    api_key = "AIzaSyDFFVUkYavn8C3BMAssUShtVVz7NAupOlE"
    video_id = input("Enter the YouTube video ID: ")

    youtube_api_service = get_youtube_api_service(api_key)
    captions = get_video_captions(youtube_api_service, video_id)

    if captions:
        print("English Transcripts:")
        for caption in captions:
            caption_text = get_caption_text(youtube_api_service, caption['id'])
            print(caption_text)
    else:
        print("No English captions found for this video.")

if __name__ == "__main__":
    main()
# Out:
# Enter the YouTube video ID:  GFZcofFODYw
# English Transcripts:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[7], line 40
#      37         print("No English captions found for this video.")
#      39 if __name__ == "__main__":
# ---> 40     main()
#
# Cell In[7], line 34, in main()
#      32     print("English Transcripts:")
#      33     for caption in captions:
# ---> 34         caption_text = get_caption_text(youtube_api_service, caption['id'])
#      35         print(caption_text)
#      36 else:
#
# Cell In[7], line 19, in get_caption_text(api_service, caption_id)
#      16 def get_caption_text(api_service, caption_id):
#      17     caption_response = api_service.captions().download(
#      18         id=caption_id
# ---> 19     ).execute()
#      21     return caption_response.decode('utf-8')
#
# ...
